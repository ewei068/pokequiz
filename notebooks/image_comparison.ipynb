# %%
import json
from PIL import Image, ImageDraw
import io
from tqdm import tqdm

from matplotlib.pyplot import figure, imshow, axis
from matplotlib.image import imread

# %%
dataset_path = "../data/pokemon_data.json"

# %%
def load_json(path):
    # Opening JSON file
    with open(path, 'r') as openfile:
        # Reading from json file
        json_object = json.load(openfile)
        return json_object

# %%
all_pokemon_data = load_json(dataset_path)

# %%
# create silhouettes
all_similarities = {}
for pid1 in tqdm(all_pokemon_data):
    try:
        img1 = Image.open("../data/client_data/mystery_sprites/%s.png"%pid1).convert("RGBA")
    except:
        continue
    
    similarities = []
    for pid2 in all_pokemon_data:
        if pid1 == pid2:
            continue
        try:
            img2 = Image.open("../data/client_data/mystery_sprites/%s.png"%pid2).convert("RGBA")
        except:
            continue
        
        similarity = 0
        for x in range(img1.width):
            for y in range(img1.height):
                if img1.getpixel((x, y)) == img2.getpixel((x, y)):
                    similarity += 1
                else:
                    similarity -= 1
        similarities.append((pid2, similarity / (img1.width * img1.height)))
    
    similarities.sort(key = lambda x: x[1], reverse=True)
    all_similarities[pid1] = similarities
    '''num_images = 5
    fig = figure()
    for i in range(num_images):
        a=fig.add_subplot(1,num_images,i+1)
        if i == 0:
            pid = pid1
        else:
            pid = similarities[i-1][0]
        image = imread("../data/mystery_sprites/%s.png"%pid)
        imshow(image,cmap='Greys_r')
        axis('off')'''
# Out:
#   0%|          | 0/899 [00:00<?, ?it/s]
#
#
#
#   0%|          | 1/899 [00:12<3:08:00, 12.56s/it]
#
#
#
#   0%|          | 2/899 [00:24<3:04:02, 12.31s/it]
#
#
#
#   0%|          | 3/899 [00:36<3:01:40, 12.17s/it]
#
#
#
#   0%|          | 4/899 [00:49<3:07:01, 12.54s/it]
#
#
#
#   1%|          | 5/899 [01:02<3:09:10, 12.70s/it]
#
#
#
#   1%|          | 6/899 [01:14<3:03:45, 12.35s/it]
#
#
#
#   1%|          | 7/899 [01:26<3:02:39, 12.29s/it]
#
#
#
#   1%|          | 8/899 [01:37<2:58:46, 12.04s/it]
#
#
#
#   1%|          | 9/899 [01:49<2:58:26, 12.03s/it]
#
#
#
#   1%|          | 10/899 [02:01<2:56:41, 11.93s/it]
#
#
#
#   1%|          | 11/899 [02:12<2:54:07, 11.77s/it]
#
#
#
#   1%|▏         | 12/899 [02:24<2:52:50, 11.69s/it]
#
#
#
#   1%|▏         | 13/899 [02:35<2:51:20, 11.60s/it]
#
#
#
#   2%|▏         | 14/899 [02:47<2:50:56, 11.59s/it]
#
#
#
#   2%|▏         | 15/899 [02:58<2:50:25, 11.57s/it]
#
#
#
#   2%|▏         | 16/899 [03:10<2:49:29, 11.52s/it]
#
#
#
# ...

# %%
def save_json(object_, path):
    # Serializing json
    json_object = json.dumps(object_, indent=4)
    
    # Writing to sample.json
    with open(path, "w") as outfile:
        outfile.write(json_object)

# %%
save_json(all_similarities, "../data/client_data/sprite_similarities.json")
